# %%
import pandas as pd
from sklearn import datasets
import matplotlib.pyplot as plt
from scipy.stats import randint
import numpy as np

from sklearn.experimental import enable_halving_search_cv  # noqa
from sklearn.model_selection import HalvingRandomSearchCV
from sklearn.model_selection import HalvingGridSearchCV
from sklearn.ensemble import RandomForestClassifier

# %%
import scipy.io
data = scipy.io.loadmat('../data/url.mat')

# %%
num_of_days = 120
X, Y = [], []

for i in range(num_of_days):
    day_data = data["Day" + str(i)]
    X.append(day_data[0][0][0])
    Y.append(day_data[0][0][1])

# %%
# y-data are lists of numpy-arrays

for i in range(len(Y)):
    Y[i] = [element for sublist in Y[i] for element in sublist]
   
# y-data becomes a list of lists

# %% [markdown]
# from sklearn.svm import LinearSVC
#
# clf = LinearSVC()
#
# fits = [True, False]
# Cs = [1, 10, 100, 1e3, 1e4, 1e5]
# param_grid = {'fit_intercept': fits, 'C': Cs}
#
# gsh = HalvingGridSearchCV(
#     estimator=clf, param_grid=param_grid, factor=2)
#
# gsh.fit(X[0], Y[0])

# %%
from sklearn.linear_model import Perceptron

clf = Perceptron(random_state = 123)

fits = [True, False]
#Cs = [1, 10, 100, 1e3, 1e4, 1e5]

penalties = ['none', 'l1', 'l2', 'elasticnet']
#lambda_ = [0.001, 0.1, 1, 5, 10]
alphas = [0.001, 0.01, 0.1]
           
           
param_grid = {'fit_intercept': fits, 'penalty': penalties, 'alpha': alphas}

gsh = HalvingGridSearchCV(
    estimator=clf, param_grid=param_grid, factor=2)

gsh.fit(X[0], Y[0])
# Out:
# HalvingGridSearchCV(estimator=Perceptron(random_state=123), factor=2,
#                     param_grid={'alpha': [0.001, 0.01, 0.1],
#                                 'fit_intercept': [True, False],
#                                 'penalty': ['none', 'l1', 'l2', 'elasticnet']})

# %%
df = pd.DataFrame(gsh.cv_results_)
df
# Out:
#     iter  n_resources  mean_fit_time  std_fit_time  mean_score_time  \
# 0      0         1000       0.115090      0.007120         0.000448
# 1      0         1000       0.164702      0.040073         0.000442
# 2      0         1000       0.097541      0.012236         0.000610
# 3      0         1000       0.145309      0.026067         0.000617
# 4      0         1000       0.111019      0.006622         0.000430
# 5      0         1000       0.152501      0.026940         0.000431
# 6      0         1000       0.104918      0.010490         0.000626
# 7      0         1000       0.135685      0.026829         0.000620
# 8      0         1000       0.115367      0.002319         0.000441
# 9      0         1000       0.098762      0.006488         0.000422
# 10     0         1000       0.166806      0.044100         0.000694
# 11     0         1000       0.175037      0.026481         0.000697
# 12     0         1000       0.117107      0.008163         0.000471
# 13     0         1000       0.104703      0.029240         0.000482
# 14     0         1000       0.113181      0.018869         0.000676
# 15     0         1000       0.235657      0.040709         0.000714
# 16     0         1000       0.113933      0.002004         0.000440
# 17     0         1000       0.081241      0.001049         0.000595
# 18     0         1000       0.237421      0.060046         0.000728
# 19     0         1000       0.253986      0.076126         0.000727
# 20     0         1000       0.113808      0.007134         0.000439
# 21     0         1000       0.109568      0.024787         0.000545
# 22     0         1000       0.215347      0.036713         0.000698
# 23     0         1000       0.297865      0.107460         0.000743
# 24     1         2000       0.106396      0.009509         0.000554
# 25     1         2000       0.148302      0.029289         0.000546
# 26     1         2000       0.208951      0.037037         0.000863
# 27     1         2000       0.161913      0.017058         0.000603
# 28     1         2000       0.165985      0.027164         0.000848
# 29     1         2000       0.171995      0.043844         0.000818
# 30     1         2000       0.142749      0.012184         0.000597
# 31     1         2000       0.146997      0.008322         0.000581
# 32     1         2000       0.147285      0.019245         0.000568
# 33     1         2000       0.140893      0.013070         0.000528
# 34     1         2000       0.141277      0.013369         0.000525
# 35     1         2000       0.134949      0.007068         0.000547
# 36     2         4000       0.171677      0.022492         0.000809
# 37     2         4000       0.178726      0.028569         0.000826
# 38     2         4000       0.168205      0.023738         0.000734
# 39     2         4000       0.167260      0.021360         0.000757
# 40     2         4000       0.165634      0.020944         0.000736
# 41     2         4000       0.167044      0.017894         0.000760
# 42     3         8000       0.227279      0.036421         0.001164
# 43     3         8000       0.226162      0.028978         0.001178
# 44     3         8000       0.227019      0.035807         0.001161
# 45     4        16000       0.357336      0.062716         0.001937
# 46     4        16000       0.358470      0.062001         0.002044
#
#     std_score_time param_alpha param_fit_intercept param_penalty  \
# 0         0.000021       0.001                True          none
# 1         0.000021       0.001                True            l1
# 2         0.000022       0.001                True            l2
# 3         0.000012       0.001                True    elasticnet
# 4         0.000003       0.001               False          none
# 5         0.000009       0.001               False            l1
# 6         0.000025       0.001               False            l2
# 7         0.000007       0.001               False    elasticnet
# 8         0.000012        0.01                True          none
# 9         0.000006        0.01                True            l1
# 10        0.000016        0.01                True            l2
# 11        0.000041        0.01                True    elasticnet
# 12        0.000041        0.01               False          none
# 13        0.000067        0.01               False            l1
# 14        0.000021        0.01               False            l2
# 15        0.000053        0.01               False    elasticnet
# 16        0.000005         0.1                True          none
# 17        0.000027         0.1                True            l1
# 18        0.000038         0.1                True            l2
# 19        0.000033         0.1                True    elasticnet
# 20        0.000005         0.1               False          none
# 21        0.000106         0.1               False            l1
# 22        0.000017         0.1               False            l2
# 23        0.000026         0.1               False    elasticnet
# 24        0.000057        0.01               False            l1
# 25        0.000038       0.001                True            l1
# 26        0.000023        0.01                True    elasticnet
# 27        0.000057       0.001               False            l1
# 28        0.000063       0.001                True    elasticnet
# 29        0.000032       0.001               False    elasticnet
# 30        0.000044        0.01                True          none
# 31        0.000048         0.1                True          none
# 32        0.000039       0.001               False          none
# 33        0.000008         0.1               False          none
# 34        0.000004        0.01               False          none
# 35        0.000025       0.001                True          none
# 36        0.000059       0.001               False          none
# 37        0.000063         0.1               False          none
# 38        0.000035        0.01               False          none
# 39        0.000046        0.01                True          none
# 40        0.000039         0.1                True          none
# 41        0.000022       0.001                True          none
# 42        0.000007        0.01                True          none
# 43        0.000031         0.1                True          none
# 44        0.000006       0.001                True          none
# 45        0.000017         0.1                True          none
# 46        0.000120       0.001                True          none
#
#                                                params  ...  mean_test_score  \
# 0   {'alpha': 0.001, 'fit_intercept': True, 'penal...  ...         0.952000
# 1   {'alpha': 0.001, 'fit_intercept': True, 'penal...  ...         0.910000
# 2   {'alpha': 0.001, 'fit_intercept': True, 'penal...  ...         0.881000
# 3   {'alpha': 0.001, 'fit_intercept': True, 'penal...  ...         0.924000
# 4   {'alpha': 0.001, 'fit_intercept': False, 'pena...  ...         0.952000
# 5   {'alpha': 0.001, 'fit_intercept': False, 'pena...  ...         0.922000
# 6   {'alpha': 0.001, 'fit_intercept': False, 'pena...  ...         0.834000
# 7   {'alpha': 0.001, 'fit_intercept': False, 'pena...  ...         0.933000
# 8   {'alpha': 0.01, 'fit_intercept': True, 'penalt...  ...         0.952000
# 9   {'alpha': 0.01, 'fit_intercept': True, 'penalt...  ...         0.808000
# 10  {'alpha': 0.01, 'fit_intercept': True, 'penalt...  ...         0.815000
# 11  {'alpha': 0.01, 'fit_intercept': True, 'penalt...  ...         0.912000
# 12  {'alpha': 0.01, 'fit_intercept': False, 'penal...  ...         0.952000
# 13  {'alpha': 0.01, 'fit_intercept': False, 'penal...  ...         0.902000
# 14  {'alpha': 0.01, 'fit_intercept': False, 'penal...  ...         0.824000
# 15  {'alpha': 0.01, 'fit_intercept': False, 'penal...  ...         0.884000
# 16  {'alpha': 0.1, 'fit_intercept': True, 'penalty...  ...         0.952000
# 17  {'alpha': 0.1, 'fit_intercept': True, 'penalty...  ...         0.599000
# 18  {'alpha': 0.1, 'fit_intercept': True, 'penalty...  ...         0.547000
# 19  {'alpha': 0.1, 'fit_intercept': True, 'penalty...  ...         0.817000
# 20  {'alpha': 0.1, 'fit_intercept': False, 'penalt...  ...         0.952000
# 21  {'alpha': 0.1, 'fit_intercept': False, 'penalt...  ...         0.715000
# 22  {'alpha': 0.1, 'fit_intercept': False, 'penalt...  ...         0.547000
# 23  {'alpha': 0.1, 'fit_intercept': False, 'penalt...  ...         0.875000
# 24  {'alpha': 0.01, 'fit_intercept': False, 'penal...  ...         0.922000
# 25  {'alpha': 0.001, 'fit_intercept': True, 'penal...  ...         0.960000
# 26  {'alpha': 0.01, 'fit_intercept': True, 'penalt...  ...         0.885000
# 27  {'alpha': 0.001, 'fit_intercept': False, 'pena...  ...         0.938500
# 28  {'alpha': 0.001, 'fit_intercept': True, 'penal...  ...         0.933000
# 29  {'alpha': 0.001, 'fit_intercept': False, 'pena...  ...         0.943500
# 30  {'alpha': 0.01, 'fit_intercept': True, 'penalt...  ...         0.970500
# 31  {'alpha': 0.1, 'fit_intercept': True, 'penalty...  ...         0.970500
# 32  {'alpha': 0.001, 'fit_intercept': False, 'pena...  ...         0.970500
# 33  {'alpha': 0.1, 'fit_intercept': False, 'penalt...  ...         0.970500
# 34  {'alpha': 0.01, 'fit_intercept': False, 'penal...  ...         0.970500
# 35  {'alpha': 0.001, 'fit_intercept': True, 'penal...  ...         0.970500
# 36  {'alpha': 0.001, 'fit_intercept': False, 'pena...  ...         0.966750
# 37  {'alpha': 0.1, 'fit_intercept': False, 'penalt...  ...         0.966750
# 38  {'alpha': 0.01, 'fit_intercept': False, 'penal...  ...         0.966750
# 39  {'alpha': 0.01, 'fit_intercept': True, 'penalt...  ...         0.967250
# 40  {'alpha': 0.1, 'fit_intercept': True, 'penalty...  ...         0.967250
# 41  {'alpha': 0.001, 'fit_intercept': True, 'penal...  ...         0.967250
# 42  {'alpha': 0.01, 'fit_intercept': True, 'penalt...  ...         0.969250
# 43  {'alpha': 0.1, 'fit_intercept': True, 'penalty...  ...         0.969250
# 44  {'alpha': 0.001, 'fit_intercept': True, 'penal...  ...         0.969250
# 45  {'alpha': 0.1, 'fit_intercept': True, 'penalty...  ...         0.974312
# 46  {'alpha': 0.001, 'fit_intercept': True, 'penal...  ...         0.974312
#
#     std_test_score  rank_test_score  split0_train_score  split1_train_score  \
# 0         0.008718               19            1.000000            1.000000
# 1         0.035355               33            0.871250            0.910000
# 2         0.064607               37            0.818750            0.982500
# 3         0.029900               29            0.983750            0.980000
# 4         0.008718               19            1.000000            1.000000
# 5         0.022935               30            0.896250            0.977500
# 6         0.066363               39            0.937500            0.815000
# 7         0.016000               27            0.960000            0.976250
# 8         0.008718               19            1.000000            1.000000
# 9         0.124242               43            0.752500            0.786250
# 10        0.048785               42            0.688750            0.801250
# 11        0.058703               32            0.932500            0.958750
# 12        0.008718               19            1.000000            1.000000
# 13        0.043658               34            0.941250            0.947500
# 14        0.076250               40            0.892500            0.872500
# 15        0.066888               36            0.836250            0.736250
# 16        0.008718               19            1.000000            1.000000
# 17        0.207302               45            0.603750            0.342500
# 18        0.132008               46            0.395000            0.342500
# 19        0.127146               41            0.793750            0.657500
# 20        0.008718               19            1.000000            1.000000
# 21        0.088148               44            0.793750            0.657500
# 22        0.132008               46            0.395000            0.342500
# 23        0.048477               38            0.793750            0.931250
# 24        0.055304               30            0.945000            0.936875
# 25        0.008367               18            0.962500            0.943750
# 26        0.104821               35            0.957500            0.905625
# 27        0.042444               26            0.846875            0.955000
# 28        0.029850               28            0.970625            0.906875
# 29        0.023801               25            0.975625            0.945000
# 30        0.009798                3            1.000000            1.000000
# 31        0.009798                3            1.000000            1.000000
# 32        0.008860                6            1.000000            1.000000
# 33        0.008860                6            1.000000            1.000000
# 34        0.008860                6            1.000000            1.000000
# 35        0.009798                3            1.000000            1.000000
# 36        0.009172               15            1.000000            0.995625
# 37        0.009172               15            1.000000            0.995625
# 38        0.009172               15            1.000000            0.995625
# 39        0.009533               12            1.000000            1.000000
# 40        0.009533               12            1.000000            1.000000
# 41        0.009533               12            1.000000            1.000000
# 42        0.003544                9            1.000000            0.999687
# 43        0.003544                9            1.000000            0.999687
# 44        0.003544                9            1.000000            0.999687
# 45        0.002408                1            1.000000            1.000000
# 46        0.002408                1            1.000000            1.000000
#
#     split2_train_score  split3_train_score  split4_train_score  \
# 0             1.000000            1.000000            1.000000
# 1             0.970000            0.980000            0.975000
# 2             0.987500            0.990000            0.867500
# 3             0.985000            0.948750            0.923750
# 4             1.000000            1.000000            1.000000
# 5             0.965000            0.977500            0.990000
# 6             0.961250            0.826250            0.867500
# 7             0.966250            0.950000            0.963750
# 8             1.000000            1.000000            1.000000
# 9             0.960000            0.960000            0.618750
# 10            0.865000            0.870000            0.915000
# 11            0.971250            0.847500            0.950000
# 12            1.000000            1.000000            1.000000
# 13            0.861250            0.843750            0.963750
# 14            0.865000            0.830000            0.718750
# 15            0.961250            0.965000            0.946250
# 16            1.000000            1.000000            1.000000
# 17            0.952500            0.366250            0.617500
# 18            0.665000            0.717500            0.625000
# 19            0.913750            0.960000            0.865000
# 20            1.000000            1.000000            1.000000
# 21            0.827500            0.633750            0.828750
# 22            0.665000            0.717500            0.625000
# 23            0.851250            0.945000            0.890000
# 24            0.850625            0.947500            0.957500
# 25            0.953750            0.968125            0.967500
# 26            0.955625            0.920000            0.738125
# 27            0.971250            0.959375            0.973750
# 28            0.929375            0.975625            0.968125
# 29            0.980625            0.953125            0.937500
# 30            1.000000            1.000000            1.000000
# 31            1.000000            1.000000            1.000000
# 32            1.000000            1.000000            1.000000
# 33            1.000000            1.000000            1.000000
# 34            1.000000            1.000000            1.000000
# 35            1.000000            1.000000            1.000000
# 36            1.000000            1.000000            1.000000
# 37            1.000000            1.000000            1.000000
# 38            1.000000            1.000000            1.000000
# 39            1.000000            1.000000            1.000000
# 40            1.000000            1.000000            1.000000
# 41            1.000000            1.000000            1.000000
# 42            1.000000            1.000000            0.998750
# 43            1.000000            1.000000            0.998750
# 44            1.000000            1.000000            0.998750
# 45            1.000000            0.997812            0.998984
# 46            1.000000            0.997812            0.998984
#
#     mean_train_score  std_train_score
# 0           1.000000         0.000000
# 1           0.941250         0.043229
# 2           0.929250         0.072031
# 3           0.964250         0.024246
# 4           1.000000         0.000000
# 5           0.961250         0.033448
# 6           0.881500         0.058595
# 7           0.963250         0.008537
# 8           1.000000         0.000000
# 9           0.815500         0.130611
# 10          0.828000         0.078496
# 11          0.932000         0.044092
# 12          1.000000         0.000000
# 13          0.911500         0.049043
# 14          0.835750         0.061885
# 15          0.889000         0.089876
# 16          1.000000         0.000000
# 17          0.576500         0.220345
# 18          0.549000         0.150985
# 19          0.838000         0.105725
# 20          1.000000         0.000000
# 21          0.748250         0.085061
# 22          0.549000         0.150985
# 23          0.882250         0.055121
# 24          0.927500         0.038997
# 25          0.959125         0.009250
# 26          0.895375         0.081152
# 27          0.941250         0.047708
# 28          0.950125         0.027187
# 29          0.958375         0.016940
# 30          1.000000         0.000000
# 31          1.000000         0.000000
# 32          1.000000         0.000000
# 33          1.000000         0.000000
# 34          1.000000         0.000000
# 35          1.000000         0.000000
# 36          0.999125         0.001750
# 37          0.999125         0.001750
# 38          0.999125         0.001750
# 39          1.000000         0.000000
# 40          1.000000         0.000000
# 41          1.000000         0.000000
# 42          0.999687         0.000484
# 43          0.999687         0.000484
# 44          0.999687         0.000484
# 45          0.999359         0.000868
# 46          0.999359         0.000868
#
# [47 rows x 25 columns]
