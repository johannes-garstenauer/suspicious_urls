# %%
import scipy.io
data = scipy.io.loadmat('../../data/url.mat')
#'../../data/url.mat'

# %% [markdown]
# **create list for labels and data, where one entry is the data for the day with this index**

# %%
import numpy as np

num_of_days = 120
X, Y = [], []

for i in range(num_of_days):
    day_data = data["Day" + str(i)]
    X.append(day_data[0][0][0])
    Y.append(day_data[0][0][1])

# %%
for i in range(len(Y)):
    Y[i] = Y[i].ravel()

# %% [markdown]
# **continous learn classifier**

# %%
# incremental learns classifier (must have partial_fit() function)
# returns an array of cumulative error rates for each day
def learn_incremental(clf, batch_size = 1000):
    
    #print("Batch size {}".format(batch_size))
    error_rates = []
    num_of_days = 120
    err = 0
    
    for curr_day in range(num_of_days): # looping through days
    
        if (curr_day != 45):
            X_curr_day = X[curr_day]
    
            # split the data in slices of batch_size
            batches_amount = int(X_curr_day.shape[0] / batch_size)
            Y_curr_day = np.array_split(Y[curr_day], batches_amount)
    
            for j in range(batches_amount): # looping through individual urls
                select_ind = np.arange(j * batch_size, (j+1) * batch_size)
        
                X_curr_url_batch, Y_curr_url_batch = X_curr_day[select_ind,:], Y_curr_day[j] 
        
                if (j > 0):
                    Y_preds = clf.predict(X_curr_url_batch)
            
                    for k in range(batch_size):
                        if(Y_preds[k] != Y_curr_url_batch[k]):
                            err = err + 1
        
                clf.partial_fit(X_curr_url_batch, Y_curr_url_batch, classes=list(range(2))) # Continous fitting of urls and label
            
            print("Log: Day {}: {}".format(curr_day ,err / X_curr_day.shape[0]))
            error_rates.append(err / X_curr_day.shape[0])
            err = 0
    return error_rates

# %% [markdown]
# ### Batch-size and other global variables and imports:

# %%
from sklearn.metrics import accuracy_score
from sklearn.linear_model import Perceptron
from sklearn.linear_model import PassiveAggressiveClassifier
from sklearn.linear_model import SGDClassifier
import matplotlib.pyplot as plt

batch_size = 4000

# Initialize error rates of the different classifiers
error_rates_pa = None
error_rates_percep = None
error_rates_lrsgd = None

# %% [markdown]
# ### Perceptron

# %%
clf = Perceptron(random_state = 123)

error_rates_percep = learn_incremental(clf, batch_size)

cnt = 0
for x in error_rates_percep:    
    print("Error-rate Day {}   : {}".format(cnt, x))
    cnt = cnt + 1
# Out:
# Log: Day 0: 0.0275625
# Log: Day 1: 0.02685
# Log: Day 2: 0.0296
# Log: Day 3: 0.0437
# Log: Day 4: 0.0236
# Log: Day 5: 0.0249
# Log: Day 6: 0.01775
# Log: Day 7: 0.01835
# Log: Day 8: 0.01805
# Log: Day 9: 0.0275
# Log: Day 10: 0.019
# Log: Day 11: 0.02385
# Log: Day 12: 0.0175
# Log: Day 13: 0.01415
# Log: Day 14: 0.0169
# Log: Day 15: 0.0134
# Log: Day 16: 0.0211
# Log: Day 17: 0.01805
# Log: Day 18: 0.0157
# Log: Day 19: 0.0179
# Log: Day 20: 0.02135
# Log: Day 21: 0.0207
# Log: Day 22: 0.0278
# Log: Day 23: 0.0271
# Log: Day 24: 0.0215
# Log: Day 25: 0.0254
# Log: Day 26: 0.01475
# Log: Day 27: 0.0253
# Log: Day 28: 0.0208
# Log: Day 29: 0.0208
# Log: Day 30: 0.02545
# Log: Day 31: 0.0213
# Log: Day 32: 0.0174
# Log: Day 33: 0.0212
# Log: Day 34: 5e-05
# Log: Day 35: 0.02565
# Log: Day 36: 0.00075
# Log: Day 37: 5e-05
# Log: Day 38: 0.03615
# Log: Day 39: 0.0313
# Log: Day 40: 0.0232
# Error-rate Day 58   : 0.0209
# Error-rate Day 59   : 0.02225
# Error-rate Day 60   : 0.0224
# Error-rate Day 61   : 0.02315
# Error-rate Day 62   : 0.0274
# Error-rate Day 63   : 0.0208
# Error-rate Day 64   : 0.02555
# Error-rate Day 65   : 0.0213
# Error-rate Day 66   : 0.0219
# Error-rate Day 67   : 0.0213
# Error-rate Day 68   : 0.0178
# Error-rate Day 69   : 0.01975
# Error-rate Day 70   : 0.02095
# Error-rate Day 71   : 0.02
# Error-rate Day 72   : 0.0209
# Error-rate Day 73   : 0.01845
# Error-rate Day 74   : 0.0217
# Error-rate Day 75   : 0.0273
# Error-rate Day 76   : 0.0187
# Error-rate Day 77   : 0.02605
# Error-rate Day 78   : 0.02335
# Error-rate Day 79   : 0.0251
# Error-rate Day 80   : 0.02505
# Error-rate Day 81   : 0.01535
# Error-rate Day 82   : 0.0164
# Error-rate Day 83   : 0.01905
# Error-rate Day 84   : 0.02305
# Error-rate Day 85   : 0.0202
# Error-rate Day 86   : 0.02185
# Error-rate Day 87   : 0.0186
# Error-rate Day 88   : 0.0148
# Error-rate Day 89   : 0.01055
# Error-rate Day 90   : 0.01455
# Error-rate Day 91   : 0.02195
# Error-rate Day 92   : 0.02285
# Error-rate Day 93   : 0.02155
# Error-rate Day 94   : 0.00985
# Error-rate Day 95   : 0.01805
# Error-rate Day 96   : 0.02075
# Error-rate Day 97   : 0.01955
# Error-rate Day 98   : 0.0228
# Error-rate Day 99   : 0.0215
# Error-rate Day 100   : 0.0241
# Error-rate Day 101   : 0.02515
# Error-rate Day 102   : 0.01745
# Error-rate Day 103   : 0.0163
# Error-rate Day 104   : 0.02075
# Error-rate Day 105   : 0.0152
# Error-rate Day 106   : 0.01635
# Error-rate Day 107   : 0.0283
# Error-rate Day 108   : 0.0156
# Error-rate Day 109   : 0.01885
# Error-rate Day 110   : 0.01755
# Error-rate Day 111   : 0.02155
# Error-rate Day 112   : 0.0204
# Error-rate Day 113   : 0.019
# Error-rate Day 114   : 0.0221
# Error-rate Day 115   : 0.0311
# Error-rate Day 116   : 0.0238
# Error-rate Day 117   : 0.0223
# Error-rate Day 118   : 0.0198

# %% [markdown]
# ### Passive Aggressive

# %%
clf = PassiveAggressiveClassifier(C=0.001, random_state = 123)

error_rates_pa = learn_incremental(clf, batch_size)

cnt = 0
for x in error_rates_pa:    
    print("Error-rate Day {}   : {}".format(cnt, x))
    cnt = cnt + 1
# Out:
# Log: Day 0: 0.0295625
# Log: Day 1: 0.0264
# Log: Day 2: 0.022
# Log: Day 3: 0.0206
# Log: Day 4: 0.0222
# Log: Day 5: 0.0217
# Log: Day 6: 0.01735
# Log: Day 7: 0.0228
# Log: Day 8: 0.01905
# Log: Day 9: 0.0223
# Log: Day 10: 0.02165
# Log: Day 11: 0.0193
# Log: Day 12: 0.02005
# Log: Day 13: 0.01565
# Log: Day 14: 0.0182
# Log: Day 15: 0.01575
# Log: Day 16: 0.0162
# Log: Day 17: 0.0164
# Log: Day 18: 0.0166
# Log: Day 19: 0.0155
# Error-rate Day 89   : 0.00665
# Error-rate Day 90   : 0.0109
# Error-rate Day 91   : 0.01445
# Error-rate Day 92   : 0.01445
# Error-rate Day 93   : 0.0114
# Error-rate Day 94   : 0.0058
# Error-rate Day 95   : 0.01205
# Error-rate Day 96   : 0.0124
# Error-rate Day 97   : 0.01285
# Error-rate Day 98   : 0.0144
# Error-rate Day 99   : 0.01515
# Error-rate Day 100   : 0.01645
# Error-rate Day 101   : 0.0178
# Error-rate Day 102   : 0.0118
# Error-rate Day 103   : 0.01155
# Error-rate Day 104   : 0.01305
# Error-rate Day 105   : 0.0102
# Error-rate Day 106   : 0.0103
# Error-rate Day 107   : 0.01855
# Error-rate Day 108   : 0.0115
# Error-rate Day 109   : 0.01285
# Error-rate Day 110   : 0.01185
# Error-rate Day 111   : 0.0137
# Error-rate Day 112   : 0.01305
# Error-rate Day 113   : 0.01335
# Error-rate Day 114   : 0.0166
# Error-rate Day 115   : 0.02065
# Error-rate Day 116   : 0.0179
# Error-rate Day 117   : 0.01625
# Error-rate Day 118   : 0.01315

# %%
def cleanup(x, y):
    
    # Cleanup outliers in data
    outliers = []
    for i in range(len(y)):
        if (y[i] > 3.4 or y[i] < 0.5):
            outliers = np.append(outliers, i)
    
    offset = 0
    for outl in outliers:
        y = np.delete(y, int(outl) - offset)
        x = x[:-1]
        offset = offset + 1
        
    return x, y

# %%
def _calc_line(x, y):
    
    # create polynomial equation and calculate line
    theta = np.polyfit(x, y, 8)
    return theta[8] + theta[7] * pow(x, 1) + theta[6] * pow(x, 2) + theta[5] * pow(x, 3) + theta[4] * pow(x, 4) + theta[3] * pow(x, 5) + theta[2] * pow(x, 6) + theta[1] * pow(x, 7) + theta[0] * pow(x, 8)

# %%
def _plot(y, color, marker, linestyle, scatter, label):
    
    # Set up the day_indexes with the missing 45th day in mind
    x = np.arange(0, 120) 
    
    # attend to data size imbalances (day 45 outages)
    if (y.shape[0] < x.shape[0]):
        x = x[:-1]
        
    y = y * 100
    #x, y = cleanup(x, y)
    
    if (scatter):
        plt.scatter(x, y)
        
    y = _calc_line(x, y)
    plt.plot(x, y, "{}{}{}".format(marker, color, linestyle), markevery=5, label=label)

# %%
import matplotlib.pyplot as plt

def plot8degree(error_rates_pa, error_rates_percep, error_rates_lrsgd,
                batch_size, scatter = False):

    if (error_rates_pa is not None):
        _plot(np.array(error_rates_pa), 'r', 'v', '-', scatter, "PA")
        
    if (error_rates_percep is not None):
        _plot(np.array(error_rates_percep), 'g', 'o', '-', scatter, "Perceptron")
        
    if (error_rates_lrsgd is not None):
        _plot(np.array(error_rates_lrsgd), 'b', 'x', '--', scatter, "LRsgd")
        
    title = 'Experiment 2 with batch size {}'.format(batch_size)
    plt.title(title)
    plt.xlabel('Days')
    plt.ylabel('Cumulative error rate (%)')
    plt.ylim([1,4])
    plt.xlim([0,100])
    plt.legend()
    plt.savefig("{}.svg".format(title), format='svg', dpi=1200)

# %%
plot8degree(error_rates_pa, error_rates_percep, error_rates_lrsgd,
            batch_size, True)

# %%
## Does benefit model to cleanup outliers 35-45
