# %%
import scipy.io
data = scipy.io.loadmat('../../data/url.mat')
#'../../data/url.mat'

# %% [markdown]
# **create list for labels and data, where one entry is the data for the day with this index**

# %%
import numpy as np

num_of_days = 120
X, Y = [], []

for i in range(num_of_days):
    day_data = data["Day" + str(i)]
    X.append(day_data[0][0][0])
    Y.append(day_data[0][0][1])

# %%
for i in range(len(Y)):
    Y[i] = Y[i].ravel()

# %% [markdown]
# **continous learn classifier**

# %%
# incremental learns classifier (must have partial_fit() function)
# returns an array of cumulative error rates for each day
def learn_incremental(clf, batch_size = 1000):
    
    #print("Batch size {}".format(batch_size))
    error_rates = []
    num_of_days = 120
    err = 0
    
    for curr_day in range(num_of_days): # looping through days
    
        if (curr_day != 45):
            X_curr_day = X[curr_day]
    
            # split the data in slices of batch_size
            batches_amount = int(X_curr_day.shape[0] / batch_size)
            Y_curr_day = np.array_split(Y[curr_day], batches_amount)
    
            for j in range(batches_amount): # looping through individual urls
                select_ind = np.arange(j * batch_size, (j+1) * batch_size)
        
                X_curr_url_batch, Y_curr_url_batch = X_curr_day[select_ind,:], Y_curr_day[j] 
        
                if (j > 0):
                    Y_preds = clf.predict(X_curr_url_batch)
            
                    for k in range(batch_size):
                        if(Y_preds[k] != Y_curr_url_batch[k]):
                            err = err + 1
        
                clf.partial_fit(X_curr_url_batch, Y_curr_url_batch, classes=list(range(2))) # Continous fitting of urls and label
            
            print("Log: Day {}: {}".format(curr_day ,err / X_curr_day.shape[0]))
            error_rates.append(err / X_curr_day.shape[0])
            err = 0
    return error_rates

# %% [markdown]
# ### Batch-size and other global variables and imports:

# %%
from sklearn.metrics import accuracy_score
from sklearn.linear_model import Perceptron
from sklearn.linear_model import PassiveAggressiveClassifier
from sklearn.linear_model import SGDClassifier
import matplotlib.pyplot as plt

batch_size = 4

# Initialize error rates of the different classifiers
error_rates_pa = None
error_rates_percep = None
error_rates_lrsgd = None

# %% [markdown]
# ### Perceptron

# %%
clf = Perceptron(random_state = 123)

error_rates_percep = learn_incremental(clf, batch_size)

cnt = 0
for x in error_rates_percep:    
    print("Error-rate Day {}   : {}".format(cnt, x))
    cnt = cnt + 1
# Out:
# Log: Day 0: 0.051375
# Log: Day 1: 0.03565
# Log: Day 2: 0.0252
# Log: Day 3: 0.0267
# Log: Day 4: 0.0305
# Log: Day 5: 0.0239
# Log: Day 6: 0.0233
# Log: Day 7: 0.02805
# Log: Day 8: 0.02575
# Log: Day 9: 0.03235
# Log: Day 10: 0.029
# Log: Day 11: 0.02535
# Log: Day 12: 0.02515
# Log: Day 13: 0.0192
# Log: Day 14: 0.0241
# Log: Day 15: 0.0184
# Log: Day 16: 0.0221
# Log: Day 17: 0.0204
# Log: Day 18: 0.02065
# Log: Day 19: 0.0184
# Log: Day 20: 0.0194
# Log: Day 21: 0.02545
# Log: Day 22: 0.0216
# Log: Day 23: 0.02355
# Log: Day 24: 0.0276
# Log: Day 25: 0.0294
# Log: Day 26: 0.0171
# Log: Day 27: 0.02115
# Log: Day 28: 0.0226
# Log: Day 29: 0.0245
# Log: Day 30: 0.0292
# Log: Day 31: 0.0255
# Log: Day 32: 0.0259
# Log: Day 33: 0.02375
# Log: Day 34: 0.0006
# Log: Day 35: 0.0302
# Log: Day 36: 0.0028
# Log: Day 37: 0.00025
# Log: Day 38: 0.0371
# Log: Day 39: 0.0317
# Log: Day 40: 0.0249
# Log: Day 41: 0.018
# Log: Day 42: 0.0258
# Log: Day 43: 0.0232
# Log: Day 44: 0.01345
# Log: Day 46: 0.0214
# Log: Day 47: 0.02005
# Log: Day 48: 0.0239
# Log: Day 49: 0.0276
# Log: Day 50: 0.0282
# Log: Day 51: 0.0222
# Log: Day 52: 0.0257
# Log: Day 53: 0.0268
# Log: Day 54: 0.01955
# Log: Day 55: 0.0185
# Log: Day 56: 0.0188
# Log: Day 57: 0.0184
# Log: Day 58: 0.01735
# Log: Day 59: 0.01775
# Log: Day 60: 0.0181
# Log: Day 61: 0.0159
# Log: Day 62: 0.0195
# Log: Day 63: 0.02205
# Log: Day 64: 0.01855
# Log: Day 65: 0.02205
# Log: Day 66: 0.01755
# Log: Day 67: 0.0193
# Log: Day 68: 0.0168
# Log: Day 69: 0.0148
# Log: Day 70: 0.01615
# Log: Day 71: 0.024
# Log: Day 72: 0.0204
# Log: Day 73: 0.0155
# Log: Day 74: 0.0177
# Log: Day 75: 0.02045
# Log: Day 76: 0.0177
# Log: Day 77: 0.01805
# Log: Day 78: 0.01955
# Log: Day 79: 0.0252
# Log: Day 80: 0.0224
# Log: Day 81: 0.0218
# Log: Day 82: 0.0115
# Log: Day 83: 0.01235
# Log: Day 84: 0.01685
# Log: Day 85: 0.0184
# Log: Day 86: 0.014
# Log: Day 87: 0.01175
# Log: Day 88: 0.0139
# Log: Day 89: 0.01125
# Log: Day 90: 0.0095
# Log: Day 91: 0.0122
# Log: Day 92: 0.01605
# Log: Day 93: 0.01605
# Log: Day 94: 0.01475
# Log: Day 95: 0.00775
# Log: Day 96: 0.0118
# Log: Day 97: 0.0137
# Log: Day 98: 0.01545
# Log: Day 99: 0.0158
# Log: Day 100: 0.01925
# Log: Day 101: 0.02035
# Log: Day 102: 0.02015
# Log: Day 103: 0.0163
# Log: Day 104: 0.01355
# Log: Day 105: 0.01575
# Log: Day 106: 0.0131
# Log: Day 107: 0.0131
# Log: Day 108: 0.01705
# Log: Day 109: 0.01495
# Log: Day 110: 0.0116
# Log: Day 111: 0.01325
# Log: Day 112: 0.0149
# Log: Day 113: 0.01615
# Log: Day 114: 0.01535
# Log: Day 115: 0.016
# Log: Day 116: 0.0204
# Log: Day 117: 0.013
# Log: Day 118: 0.01355
# Log: Day 119: 0.01425
# Error-rate Day 0   : 0.051375
# Error-rate Day 1   : 0.03565
# Error-rate Day 2   : 0.0252
# Error-rate Day 3   : 0.0267
# Error-rate Day 4   : 0.0305
# Error-rate Day 5   : 0.0239
# Error-rate Day 6   : 0.0233
# Error-rate Day 7   : 0.02805
# Error-rate Day 8   : 0.02575
# Error-rate Day 9   : 0.03235
# Error-rate Day 10   : 0.029
# Error-rate Day 11   : 0.02535
# Error-rate Day 12   : 0.02515
# Error-rate Day 13   : 0.0192
# Error-rate Day 14   : 0.0241
# Error-rate Day 15   : 0.0184
# Error-rate Day 16   : 0.0221
# Error-rate Day 17   : 0.0204
# Error-rate Day 18   : 0.02065
# Error-rate Day 19   : 0.0184
# Error-rate Day 20   : 0.0194
# Error-rate Day 21   : 0.02545
# Error-rate Day 22   : 0.0216
# Error-rate Day 23   : 0.02355
# Error-rate Day 24   : 0.0276
# Error-rate Day 25   : 0.0294
# Error-rate Day 26   : 0.0171
# Error-rate Day 27   : 0.02115
# Error-rate Day 28   : 0.0226
# Error-rate Day 29   : 0.0245
# Error-rate Day 30   : 0.0292
# Error-rate Day 31   : 0.0255
# Error-rate Day 32   : 0.0259
# Error-rate Day 33   : 0.02375
# Error-rate Day 34   : 0.0006
# Error-rate Day 35   : 0.0302
# Error-rate Day 36   : 0.0028
# Error-rate Day 37   : 0.00025
# Error-rate Day 38   : 0.0371
# Error-rate Day 39   : 0.0317
# Error-rate Day 40   : 0.0249
# Error-rate Day 41   : 0.018
# Error-rate Day 42   : 0.0258
# Error-rate Day 43   : 0.0232
# Error-rate Day 44   : 0.01345
# Error-rate Day 45   : 0.0214
# Error-rate Day 46   : 0.02005
# Error-rate Day 47   : 0.0239
# Error-rate Day 48   : 0.0276
# Error-rate Day 49   : 0.0282
# Error-rate Day 50   : 0.0222
# Error-rate Day 51   : 0.0257
# Error-rate Day 52   : 0.0268
# Error-rate Day 53   : 0.01955
# Error-rate Day 54   : 0.0185
# Error-rate Day 55   : 0.0188
# Error-rate Day 56   : 0.0184
# Error-rate Day 57   : 0.01735
# Error-rate Day 58   : 0.01775
# Error-rate Day 59   : 0.0181
# Error-rate Day 60   : 0.0159
# Error-rate Day 61   : 0.0195
# Error-rate Day 62   : 0.02205
# Error-rate Day 63   : 0.01855
# Error-rate Day 64   : 0.02205
# Error-rate Day 65   : 0.01755
# Error-rate Day 66   : 0.0193
# Error-rate Day 67   : 0.0168
# Error-rate Day 68   : 0.0148
# Error-rate Day 69   : 0.01615
# Error-rate Day 70   : 0.024
# Error-rate Day 71   : 0.0204
# Error-rate Day 72   : 0.0155
# Error-rate Day 73   : 0.0177
# Error-rate Day 74   : 0.02045
# Error-rate Day 75   : 0.0177
# Error-rate Day 76   : 0.01805
# Error-rate Day 77   : 0.01955
# Error-rate Day 78   : 0.0252
# Error-rate Day 79   : 0.0224
# Error-rate Day 80   : 0.0218
# Error-rate Day 81   : 0.0115
# Error-rate Day 82   : 0.01235
# Error-rate Day 83   : 0.01685
# Error-rate Day 84   : 0.0184
# Error-rate Day 85   : 0.014
# Error-rate Day 86   : 0.01175
# Error-rate Day 87   : 0.0139
# Error-rate Day 88   : 0.01125
# Error-rate Day 89   : 0.0095
# Error-rate Day 90   : 0.0122
# Error-rate Day 91   : 0.01605
# Error-rate Day 92   : 0.01605
# Error-rate Day 93   : 0.01475
# Error-rate Day 94   : 0.00775
# Error-rate Day 95   : 0.0118
# Error-rate Day 96   : 0.0137
# Error-rate Day 97   : 0.01545
# Error-rate Day 98   : 0.0158
# Error-rate Day 99   : 0.01925
# Error-rate Day 100   : 0.02035
# Error-rate Day 101   : 0.02015
# Error-rate Day 102   : 0.0163
# Error-rate Day 103   : 0.01355
# Error-rate Day 104   : 0.01575
# Error-rate Day 105   : 0.0131
# Error-rate Day 106   : 0.0131
# Error-rate Day 107   : 0.01705
# Error-rate Day 108   : 0.01495
# Error-rate Day 109   : 0.0116
# Error-rate Day 110   : 0.01325
# Error-rate Day 111   : 0.0149
# Error-rate Day 112   : 0.01615
# Error-rate Day 113   : 0.01535
# Error-rate Day 114   : 0.016
# Error-rate Day 115   : 0.0204
# Error-rate Day 116   : 0.013
# Error-rate Day 117   : 0.01355
# Error-rate Day 118   : 0.01425

# %% [markdown]
# ### LrSGD

# %%
clf = SGDClassifier(loss = 'log', alpha=0.001)

error_rates_lrsgd = learn_incremental(clf, batch_size)

cnt = 0
for x in error_rates_lrsgd:    
    print("Error-rate Day {}   : {}".format(cnt, x))
    cnt = cnt + 1
# Out:
# Log: Day 0: 0.0448125
# Log: Day 1: 0.0263
# Log: Day 2: 0.01785
# Log: Day 3: 0.02035
# Log: Day 4: 0.02325
# Log: Day 5: 0.021
# Log: Day 6: 0.0209
# Log: Day 7: 0.0233
# Log: Day 8: 0.0232
# Log: Day 9: 0.0266
# Log: Day 10: 0.0251
# Log: Day 11: 0.0223
# Log: Day 12: 0.02365
# Log: Day 13: 0.01885
# Log: Day 14: 0.02425
# Log: Day 15: 0.0199
# Log: Day 16: 0.0214
# Log: Day 17: 0.02085
# Log: Day 18: 0.0215
# Log: Day 19: 0.01955
# Log: Day 20: 0.0225
# Log: Day 21: 0.02935
# Log: Day 22: 0.0269
# Log: Day 23: 0.0281
# Log: Day 24: 0.03095
# Log: Day 25: 0.02925
# Log: Day 26: 0.0207
# Log: Day 27: 0.0274
# Log: Day 28: 0.0255
# Log: Day 29: 0.02725
# Log: Day 30: 0.03525
# Log: Day 31: 0.031
# Log: Day 32: 0.0292
# Log: Day 33: 0.0293
# Log: Day 34: 0.0009
# Log: Day 35: 0.0364
# Log: Day 36: 0.0073
# Log: Day 37: 0.00265
# Log: Day 38: 0.04755
# Log: Day 39: 0.0425
# Log: Day 40: 0.03145
# Log: Day 41: 0.02685
# Log: Day 42: 0.0341
# Log: Day 43: 0.03175
# Log: Day 44: 0.02055
# Log: Day 46: 0.0259
# Log: Day 47: 0.02475
# Log: Day 48: 0.03445
# Log: Day 49: 0.0355
# Log: Day 50: 0.0349
# Log: Day 51: 0.0279
# Log: Day 52: 0.02925
# Log: Day 53: 0.0313
# Log: Day 54: 0.0263
# Log: Day 55: 0.0232
# Log: Day 56: 0.0249
# Log: Day 57: 0.0242
# Log: Day 58: 0.02595
# Log: Day 59: 0.02725
# Log: Day 60: 0.0286
# Log: Day 61: 0.02595
# Log: Day 62: 0.0283
# Log: Day 63: 0.03185
# Log: Day 64: 0.02605
# Log: Day 65: 0.03135
# Log: Day 66: 0.0265
# Log: Day 67: 0.02575
# Log: Day 68: 0.0257
# Log: Day 69: 0.0204
# Log: Day 70: 0.0236
# Log: Day 71: 0.0243
# Log: Day 72: 0.02175
# Log: Day 73: 0.02275
# Log: Day 74: 0.0206
# Log: Day 75: 0.02715
# Log: Day 76: 0.0338
# Log: Day 77: 0.0244
# Log: Day 78: 0.03175
# Log: Day 79: 0.0309
# Log: Day 80: 0.03295
# Log: Day 81: 0.0309
# Log: Day 82: 0.02015
# Log: Day 83: 0.01945
# Log: Day 84: 0.02295
# Log: Day 85: 0.0282
# Log: Day 86: 0.0236
# Log: Day 87: 0.022
# Log: Day 88: 0.02185
# Log: Day 89: 0.0192
# Log: Day 90: 0.01515
# Log: Day 91: 0.019
# Log: Day 92: 0.0251
# Log: Day 93: 0.02635
# Log: Day 94: 0.02345
# Log: Day 95: 0.01305
# Log: Day 96: 0.02045
# Log: Day 97: 0.0235
# Log: Day 98: 0.0234
# Log: Day 99: 0.02755
# Log: Day 100: 0.0293
# Log: Day 101: 0.029
# Log: Day 102: 0.02995
# Log: Day 103: 0.02205
# Log: Day 104: 0.0185
# Log: Day 105: 0.0244
# Log: Day 106: 0.02035
# Log: Day 107: 0.0201
# Log: Day 108: 0.032
# Log: Day 109: 0.0193
# Log: Day 110: 0.0216
# Log: Day 111: 0.0223
# Log: Day 112: 0.0251
# Log: Day 113: 0.02535
# Log: Day 114: 0.02325
# Log: Day 115: 0.02565
# Log: Day 116: 0.0352
# Log: Day 117: 0.0274
# Log: Day 118: 0.0255
# Log: Day 119: 0.0222
# Error-rate Day 0   : 0.0448125
# Error-rate Day 1   : 0.0263
# Error-rate Day 2   : 0.01785
# Error-rate Day 3   : 0.02035
# Error-rate Day 4   : 0.02325
# Error-rate Day 5   : 0.021
# Error-rate Day 6   : 0.0209
# Error-rate Day 7   : 0.0233
# Error-rate Day 8   : 0.0232
# Error-rate Day 9   : 0.0266
# Error-rate Day 10   : 0.0251
# Error-rate Day 11   : 0.0223
# Error-rate Day 12   : 0.02365
# Error-rate Day 13   : 0.01885
# Error-rate Day 14   : 0.02425
# Error-rate Day 15   : 0.0199
# Error-rate Day 16   : 0.0214
# Error-rate Day 17   : 0.02085
# Error-rate Day 18   : 0.0215
# Error-rate Day 19   : 0.01955
# Error-rate Day 20   : 0.0225
# Error-rate Day 21   : 0.02935
# Error-rate Day 22   : 0.0269
# Error-rate Day 23   : 0.0281
# Error-rate Day 24   : 0.03095
# Error-rate Day 25   : 0.02925
# Error-rate Day 26   : 0.0207
# Error-rate Day 27   : 0.0274
# Error-rate Day 28   : 0.0255
# Error-rate Day 29   : 0.02725
# Error-rate Day 30   : 0.03525
# Error-rate Day 31   : 0.031
# Error-rate Day 32   : 0.0292
# Error-rate Day 33   : 0.0293
# Error-rate Day 34   : 0.0009
# Error-rate Day 35   : 0.0364
# Error-rate Day 36   : 0.0073
# Error-rate Day 37   : 0.00265
# Error-rate Day 38   : 0.04755
# Error-rate Day 39   : 0.0425
# Error-rate Day 40   : 0.03145
# Error-rate Day 41   : 0.02685
# Error-rate Day 42   : 0.0341
# Error-rate Day 43   : 0.03175
# Error-rate Day 44   : 0.02055
# Error-rate Day 45   : 0.0259
# Error-rate Day 46   : 0.02475
# Error-rate Day 47   : 0.03445
# Error-rate Day 48   : 0.0355
# Error-rate Day 49   : 0.0349
# Error-rate Day 50   : 0.0279
# Error-rate Day 51   : 0.02925
# Error-rate Day 52   : 0.0313
# Error-rate Day 53   : 0.0263
# Error-rate Day 54   : 0.0232
# Error-rate Day 55   : 0.0249
# Error-rate Day 56   : 0.0242
# Error-rate Day 57   : 0.02595
# Error-rate Day 58   : 0.02725
# Error-rate Day 59   : 0.0286
# Error-rate Day 60   : 0.02595
# Error-rate Day 61   : 0.0283
# Error-rate Day 62   : 0.03185
# Error-rate Day 63   : 0.02605
# Error-rate Day 64   : 0.03135
# Error-rate Day 65   : 0.0265
# Error-rate Day 66   : 0.02575
# Error-rate Day 67   : 0.0257
# Error-rate Day 68   : 0.0204
# Error-rate Day 69   : 0.0236
# Error-rate Day 70   : 0.0243
# Error-rate Day 71   : 0.02175
# Error-rate Day 72   : 0.02275
# Error-rate Day 73   : 0.0206
# Error-rate Day 74   : 0.02715
# Error-rate Day 75   : 0.0338
# Error-rate Day 76   : 0.0244
# Error-rate Day 77   : 0.03175
# Error-rate Day 78   : 0.0309
# Error-rate Day 79   : 0.03295
# Error-rate Day 80   : 0.0309
# Error-rate Day 81   : 0.02015
# Error-rate Day 82   : 0.01945
# Error-rate Day 83   : 0.02295
# Error-rate Day 84   : 0.0282
# Error-rate Day 85   : 0.0236
# Error-rate Day 86   : 0.022
# Error-rate Day 87   : 0.02185
# Error-rate Day 88   : 0.0192
# Error-rate Day 89   : 0.01515
# Error-rate Day 90   : 0.019
# Error-rate Day 91   : 0.0251
# Error-rate Day 92   : 0.02635
# Error-rate Day 93   : 0.02345
# Error-rate Day 94   : 0.01305
# Error-rate Day 95   : 0.02045
# Error-rate Day 96   : 0.0235
# Error-rate Day 97   : 0.0234
# Error-rate Day 98   : 0.02755
# Error-rate Day 99   : 0.0293
# Error-rate Day 100   : 0.029
# Error-rate Day 101   : 0.02995
# Error-rate Day 102   : 0.02205
# Error-rate Day 103   : 0.0185
# Error-rate Day 104   : 0.0244
# Error-rate Day 105   : 0.02035
# Error-rate Day 106   : 0.0201
# Error-rate Day 107   : 0.032
# Error-rate Day 108   : 0.0193
# Error-rate Day 109   : 0.0216
# Error-rate Day 110   : 0.0223
# Error-rate Day 111   : 0.0251
# Error-rate Day 112   : 0.02535
# Error-rate Day 113   : 0.02325
# Error-rate Day 114   : 0.02565
# Error-rate Day 115   : 0.0352
# Error-rate Day 116   : 0.0274
# Error-rate Day 117   : 0.0255
# Error-rate Day 118   : 0.0222

# %% [markdown]
# ### Passive Aggressive

# %%
clf = PassiveAggressiveClassifier(C=0.001, random_state = 123)

error_rates_pa = learn_incremental(clf, batch_size)

cnt = 0
for x in error_rates_pa:    
    print("Error-rate Day {}   : {}".format(cnt, x))
    cnt = cnt + 1
# Out:
# Log: Day 0: 0.0489375
# Log: Day 1: 0.0315
# Log: Day 2: 0.02365
# Log: Day 3: 0.0229
# Log: Day 4: 0.0265
# Log: Day 5: 0.02545
# Log: Day 6: 0.0226
# Log: Day 7: 0.0259
# Log: Day 8: 0.0235
# Log: Day 9: 0.02865
# Log: Day 10: 0.0251
# Log: Day 11: 0.02235
# Log: Day 12: 0.02365
# Log: Day 13: 0.01875
# Log: Day 14: 0.02365
# Log: Day 15: 0.01895
# Log: Day 16: 0.02015
# Log: Day 17: 0.01955
# Log: Day 18: 0.01985
# Log: Day 19: 0.0183
# Log: Day 20: 0.0204
# Log: Day 21: 0.0265
# Log: Day 22: 0.0226
# Log: Day 23: 0.02485
# Log: Day 24: 0.0273
# Log: Day 25: 0.02665
# Log: Day 26: 0.0177
# Log: Day 27: 0.02355
# Log: Day 28: 0.0214
# Log: Day 29: 0.02335
# Log: Day 30: 0.03085
# Log: Day 31: 0.0264
# Log: Day 32: 0.0256
# Log: Day 33: 0.0253
# Log: Day 34: 0.00055
# Log: Day 35: 0.03045
# Log: Day 36: 0.00455
# Log: Day 37: 0.001
# Log: Day 38: 0.036
# Log: Day 39: 0.03545
# Log: Day 40: 0.0244
# Log: Day 41: 0.02025
# Log: Day 42: 0.0267
# Log: Day 43: 0.0228
# Log: Day 44: 0.01535
# Log: Day 46: 0.02075
# Log: Day 47: 0.01925
# Log: Day 48: 0.0239
# Log: Day 49: 0.02625
# Log: Day 50: 0.02575
# Log: Day 51: 0.0209
# Log: Day 52: 0.02115
# Log: Day 53: 0.025
# Log: Day 54: 0.01825
# Log: Day 55: 0.01725
# Log: Day 56: 0.0187
# Log: Day 57: 0.01835
# Log: Day 58: 0.01805
# Log: Day 59: 0.0183
# Log: Day 60: 0.01835
# Log: Day 61: 0.017
# Log: Day 62: 0.0185
# Log: Day 63: 0.02225
# Log: Day 64: 0.0182
# Log: Day 65: 0.02165
# Log: Day 66: 0.01755
# Log: Day 67: 0.01765
# Log: Day 68: 0.01745
# Log: Day 69: 0.01485
# Log: Day 70: 0.0171
# Log: Day 71: 0.0188
# Log: Day 72: 0.01755
# Log: Day 73: 0.01715
# Log: Day 74: 0.01555
# Log: Day 75: 0.0198
# Log: Day 76: 0.02205
# Log: Day 77: 0.0154
# Log: Day 78: 0.0196
# Log: Day 79: 0.02365
# Log: Day 80: 0.02215
# Log: Day 81: 0.02135
# Log: Day 82: 0.01255
# Log: Day 83: 0.014
# Log: Day 84: 0.016
# Log: Day 85: 0.01805
# Log: Day 86: 0.01495
# Log: Day 87: 0.0128
# Log: Day 88: 0.01395
# Log: Day 89: 0.01155
# Log: Day 90: 0.0086
# Log: Day 91: 0.01235
# Log: Day 92: 0.0154
# Log: Day 93: 0.01685
# Log: Day 94: 0.0126
# Log: Day 95: 0.00725
# Log: Day 96: 0.01265
# Log: Day 97: 0.0149
# Log: Day 98: 0.014
# Log: Day 99: 0.0161
# Log: Day 100: 0.0197
# Log: Day 101: 0.01785
# Log: Day 102: 0.0196
# Log: Day 103: 0.0147
# Log: Day 104: 0.01265
# Log: Day 105: 0.0161
# Log: Day 106: 0.0128
# Log: Day 107: 0.0123
# Log: Day 108: 0.0171
# Log: Day 109: 0.0131
# Log: Day 110: 0.014
# Log: Day 111: 0.0132
# Log: Day 112: 0.0149
# Log: Day 113: 0.0157
# Log: Day 114: 0.01505
# Log: Day 115: 0.0166
# Log: Day 116: 0.02305
# Log: Day 117: 0.01375
# Log: Day 118: 0.0148
# Log: Day 119: 0.0143
# Error-rate Day 0   : 0.0489375
# Error-rate Day 1   : 0.0315
# Error-rate Day 2   : 0.02365
# Error-rate Day 3   : 0.0229
# Error-rate Day 4   : 0.0265
# Error-rate Day 5   : 0.02545
# Error-rate Day 6   : 0.0226
# Error-rate Day 7   : 0.0259
# Error-rate Day 8   : 0.0235
# Error-rate Day 9   : 0.02865
# Error-rate Day 10   : 0.0251
# Error-rate Day 11   : 0.02235
# Error-rate Day 12   : 0.02365
# Error-rate Day 13   : 0.01875
# Error-rate Day 14   : 0.02365
# Error-rate Day 15   : 0.01895
# Error-rate Day 16   : 0.02015
# Error-rate Day 17   : 0.01955
# Error-rate Day 18   : 0.01985
# Error-rate Day 19   : 0.0183
# Error-rate Day 20   : 0.0204
# Error-rate Day 21   : 0.0265
# Error-rate Day 22   : 0.0226
# Error-rate Day 23   : 0.02485
# Error-rate Day 24   : 0.0273
# Error-rate Day 25   : 0.02665
# Error-rate Day 26   : 0.0177
# Error-rate Day 27   : 0.02355
# Error-rate Day 28   : 0.0214
# Error-rate Day 29   : 0.02335
# Error-rate Day 30   : 0.03085
# Error-rate Day 31   : 0.0264
# Error-rate Day 32   : 0.0256
# Error-rate Day 33   : 0.0253
# Error-rate Day 34   : 0.00055
# Error-rate Day 35   : 0.03045
# Error-rate Day 36   : 0.00455
# Error-rate Day 37   : 0.001
# Error-rate Day 38   : 0.036
# Error-rate Day 39   : 0.03545
# Error-rate Day 40   : 0.0244
# Error-rate Day 41   : 0.02025
# Error-rate Day 42   : 0.0267
# Error-rate Day 43   : 0.0228
# Error-rate Day 44   : 0.01535
# Error-rate Day 45   : 0.02075
# Error-rate Day 46   : 0.01925
# Error-rate Day 47   : 0.0239
# Error-rate Day 48   : 0.02625
# Error-rate Day 49   : 0.02575
# Error-rate Day 50   : 0.0209
# Error-rate Day 51   : 0.02115
# Error-rate Day 52   : 0.025
# Error-rate Day 53   : 0.01825
# Error-rate Day 54   : 0.01725
# Error-rate Day 55   : 0.0187
# Error-rate Day 56   : 0.01835
# Error-rate Day 57   : 0.01805
# Error-rate Day 58   : 0.0183
# Error-rate Day 59   : 0.01835
# Error-rate Day 60   : 0.017
# Error-rate Day 61   : 0.0185
# Error-rate Day 62   : 0.02225
# Error-rate Day 63   : 0.0182
# Error-rate Day 64   : 0.02165
# Error-rate Day 65   : 0.01755
# Error-rate Day 66   : 0.01765
# Error-rate Day 67   : 0.01745
# Error-rate Day 68   : 0.01485
# Error-rate Day 69   : 0.0171
# Error-rate Day 70   : 0.0188
# Error-rate Day 71   : 0.01755
# Error-rate Day 72   : 0.01715
# Error-rate Day 73   : 0.01555
# Error-rate Day 74   : 0.0198
# Error-rate Day 75   : 0.02205
# Error-rate Day 76   : 0.0154
# Error-rate Day 77   : 0.0196
# Error-rate Day 78   : 0.02365
# Error-rate Day 79   : 0.02215
# Error-rate Day 80   : 0.02135
# Error-rate Day 81   : 0.01255
# Error-rate Day 82   : 0.014
# Error-rate Day 83   : 0.016
# Error-rate Day 84   : 0.01805
# Error-rate Day 85   : 0.01495
# Error-rate Day 86   : 0.0128
# Error-rate Day 87   : 0.01395
# Error-rate Day 88   : 0.01155
# Error-rate Day 89   : 0.0086
# Error-rate Day 90   : 0.01235
# Error-rate Day 91   : 0.0154
# Error-rate Day 92   : 0.01685
# Error-rate Day 93   : 0.0126
# Error-rate Day 94   : 0.00725
# Error-rate Day 95   : 0.01265
# Error-rate Day 96   : 0.0149
# Error-rate Day 97   : 0.014
# Error-rate Day 98   : 0.0161
# Error-rate Day 99   : 0.0197
# Error-rate Day 100   : 0.01785
# Error-rate Day 101   : 0.0196
# Error-rate Day 102   : 0.0147
# Error-rate Day 103   : 0.01265
# Error-rate Day 104   : 0.0161
# Error-rate Day 105   : 0.0128
# Error-rate Day 106   : 0.0123
# Error-rate Day 107   : 0.0171
# Error-rate Day 108   : 0.0131
# Error-rate Day 109   : 0.014
# Error-rate Day 110   : 0.0132
# Error-rate Day 111   : 0.0149
# Error-rate Day 112   : 0.0157
# Error-rate Day 113   : 0.01505
# Error-rate Day 114   : 0.0166
# Error-rate Day 115   : 0.02305
# Error-rate Day 116   : 0.01375
# Error-rate Day 117   : 0.0148
# Error-rate Day 118   : 0.0143

# %%
def cleanup(x, y):
    
    # Cleanup outliers in data
    outliers = []
    for i in range(len(y)):
        if (y[i] > 3.4 or y[i] < 0.5):
            outliers = np.append(outliers, i)
    
    offset = 0
    for outl in outliers:
        y = np.delete(y, int(outl) - offset)
        x = x[:-1]
        offset = offset + 1
        
    return x, y

# %%
def _calc_line(x, y):
    
    # create polynomial equation and calculate line
    theta = np.polyfit(x, y, 8)
    return theta[8] + theta[7] * pow(x, 1) + theta[6] * pow(x, 2) + theta[5] * pow(x, 3) + theta[4] * pow(x, 4) + theta[3] * pow(x, 5) + theta[2] * pow(x, 6) + theta[1] * pow(x, 7) + theta[0] * pow(x, 8)

# %%
def _plot(y, color, marker, linestyle, scatter, label):
    
    # Set up the day_indexes with the missing 45th day in mind
    x = np.arange(0, 120) 
    
    # attend to data size imbalances (day 45 outages)
    if (y.shape[0] < x.shape[0]):
        x = x[:-1]
        
    y = y * 100
    x, y = cleanup(x, y)
    
    if (scatter):
        plt.scatter(x, y)
        
    y = _calc_line(x, y)
    plt.plot(x, y, "{}{}{}".format(marker, color, linestyle), markevery=5, label=label)

# %%
import matplotlib.pyplot as plt

def plot8degree(error_rates_pa, error_rates_percep, error_rates_lrsgd,
                batch_size, scatter = False):

    if (error_rates_pa is not None):
        _plot(np.array(error_rates_pa), 'r', 'v', '-', scatter, "PA")
        
    if (error_rates_percep is not None):
        _plot(np.array(error_rates_percep), 'g', 'o', '-', scatter, "Perceptron")
        
    if (error_rates_lrsgd is not None):
        _plot(np.array(error_rates_lrsgd), 'b', 'x', '--', scatter, "LRsgd")
        
    title = 'Experiment 2 with batch size {}'.format(batch_size)
    plt.title(title)
    plt.xlabel('Days')
    plt.ylabel('Cumulative error rate (%)')
    plt.ylim([1,4])
    plt.xlim([0,100])
    plt.legend()
    plt.savefig("{}.svg".format(title), format='svg', dpi=1200)

# %%
plot8degree(error_rates_pa, error_rates_percep, error_rates_lrsgd,
            batch_size, False)

# %%
## Does benefit model to cleanup outliers 35-45
