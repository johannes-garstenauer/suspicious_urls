# %%
import scipy.io
data = scipy.io.loadmat('../../data/url.mat')

# %% [markdown]
# **create list for labels and data, where one entry is the data for the day with this index**

# %%
import numpy as np

num_of_days = 120
X, Y = [], []

for i in range(num_of_days):
    day_data = data["Day" + str(i)]
    X.append(day_data[0][0][0])
    Y.append(day_data[0][0][1])

# %% [markdown]
# **continous learn classifier**

# %%
def fix_features(X, fixed_features_amount = 150000):
    select_ind = np.arange(0, fixed_features_amount)
    return X[:,select_ind]

# %%
# incremental learns classifier (must have partial_fit() function)
# returns an array of cumulative error rates for each day
def learn_incremental(clf, batch_size = 1000):
    
    error_rates = []
    num_of_days = 120
    err = 0
    
    for curr_day in range(num_of_days): # looping through days
    
        if (curr_day != 45):
            X_curr_day = fix_features(X[curr_day])
    
            # split the data in slices of batch_size
            batches_amount = int(X_curr_day.shape[0] / batch_size)
            Y_curr_day = np.array_split(Y[curr_day], batches_amount)
    
            for j in range(batches_amount): # looping through individual urls
                select_ind = np.arange(j * batch_size, (j+1) * batch_size)
        
                X_curr_url_batch, Y_curr_url_batch = X_curr_day[select_ind,:], Y_curr_day[j] 
        
                # flatten y to 1d
                Y_curr_url_batch = Y_curr_url_batch.ravel()
        
                if (j > 0):
                    Y_preds = clf.predict(X_curr_url_batch)
            
                    for k in range(batch_size):
                        if(Y_preds[k] != Y_curr_url_batch[k]):
                            err = err + 1
        
                clf.partial_fit(X_curr_url_batch, Y_curr_url_batch, classes=list(range(2))) # Continous fitting of urls and label
            
            error_rates.append(err / X_curr_day.shape[0])
            err = 0
    return error_rates

# %%
from sklearn.linear_model import PassiveAggressiveClassifier

clf = PassiveAggressiveClassifier(C=0.001, random_state = 123)

batch_size = 4000
error_rates = learn_incremental(clf, batch_size)

cnt = 0
for x in error_rates:    
    print("Error-rate Day {}   : {}".format(cnt, x))
    cnt = cnt + 1
# Out:
# Error-rate Day 0   : 0.038625
# Error-rate Day 1   : 0.03265
# Error-rate Day 2   : 0.0276
# Error-rate Day 3   : 0.0225
# Error-rate Day 4   : 0.02585
# Error-rate Day 5   : 0.02545
# Error-rate Day 6   : 0.02045
# Error-rate Day 7   : 0.02525
# Error-rate Day 8   : 0.02035
# Error-rate Day 9   : 0.0249
# Error-rate Day 10   : 0.0238
# Error-rate Day 11   : 0.02095
# Error-rate Day 12   : 0.02205
# Error-rate Day 13   : 0.01675
# Error-rate Day 14   : 0.02
# Error-rate Day 15   : 0.01705
# Error-rate Day 16   : 0.01825
# Error-rate Day 17   : 0.01885
# Error-rate Day 18   : 0.01855
# Error-rate Day 19   : 0.0162
# Error-rate Day 20   : 0.01975
# Error-rate Day 21   : 0.02755
# Error-rate Day 22   : 0.01875
# Error-rate Day 23   : 0.0222
# Error-rate Day 24   : 0.0261
# Error-rate Day 25   : 0.02525
# Error-rate Day 26   : 0.01745
# Error-rate Day 27   : 0.0222
# Error-rate Day 28   : 0.02055
# Error-rate Day 29   : 0.0235
# Error-rate Day 30   : 0.0292
# Error-rate Day 31   : 0.02385
# Error-rate Day 32   : 0.0247
# Error-rate Day 33   : 0.02245
# Error-rate Day 34   : 0.00045
# Error-rate Day 35   : 0.03425
# Error-rate Day 36   : 0.0046
# Error-rate Day 37   : 0.0009
# Error-rate Day 38   : 0.03745
# Error-rate Day 39   : 0.0352
# Error-rate Day 40   : 0.02485
# Error-rate Day 41   : 0.02055
# Error-rate Day 42   : 0.0241
# Error-rate Day 43   : 0.02355
# Error-rate Day 44   : 0.016
# Error-rate Day 45   : 0.01945
# Error-rate Day 46   : 0.01975
# Error-rate Day 47   : 0.0287
# Error-rate Day 48   : 0.02385
# Error-rate Day 49   : 0.0225
# Error-rate Day 50   : 0.02015
# Error-rate Day 51   : 0.02115
# Error-rate Day 52   : 0.0243
# Error-rate Day 53   : 0.01765
# Error-rate Day 54   : 0.0165
# Error-rate Day 55   : 0.01845
# Error-rate Day 56   : 0.017
# Error-rate Day 57   : 0.01735
# Error-rate Day 58   : 0.01735
# Error-rate Day 59   : 0.01795
# Error-rate Day 60   : 0.0171
# Error-rate Day 61   : 0.0185
# Error-rate Day 62   : 0.0229
# Error-rate Day 63   : 0.01725
# Error-rate Day 64   : 0.0228
# Error-rate Day 65   : 0.0175
# Error-rate Day 66   : 0.0187
# Error-rate Day 67   : 0.0168
# Error-rate Day 68   : 0.0145
# Error-rate Day 69   : 0.01695
# Error-rate Day 70   : 0.01965
# Error-rate Day 71   : 0.01735
# Error-rate Day 72   : 0.01795
# Error-rate Day 73   : 0.01645
# Error-rate Day 74   : 0.01745
# Error-rate Day 75   : 0.0197
# Error-rate Day 76   : 0.01405
# Error-rate Day 77   : 0.01805
# Error-rate Day 78   : 0.0201
# Error-rate Day 79   : 0.02065
# Error-rate Day 80   : 0.0202
# Error-rate Day 81   : 0.01135
# Error-rate Day 82   : 0.0134
# Error-rate Day 83   : 0.0156
# Error-rate Day 84   : 0.01725
# Error-rate Day 85   : 0.01425
# Error-rate Day 86   : 0.01355
# Error-rate Day 87   : 0.0138
# Error-rate Day 88   : 0.00935
# Error-rate Day 89   : 0.0071
# Error-rate Day 90   : 0.01215
# Error-rate Day 91   : 0.01625
# Error-rate Day 92   : 0.01505
# Error-rate Day 93   : 0.0137
# Error-rate Day 94   : 0.00705
# Error-rate Day 95   : 0.01345
# Error-rate Day 96   : 0.01415
# Error-rate Day 97   : 0.0159
# Error-rate Day 98   : 0.0161
# Error-rate Day 99   : 0.017
# Error-rate Day 100   : 0.01805
# Error-rate Day 101   : 0.01985
# Error-rate Day 102   : 0.01365
# Error-rate Day 103   : 0.012
# Error-rate Day 104   : 0.0145
# Error-rate Day 105   : 0.01125
# Error-rate Day 106   : 0.0122
# Error-rate Day 107   : 0.0199
# Error-rate Day 108   : 0.01365
# Error-rate Day 109   : 0.0135
# Error-rate Day 110   : 0.0132
# Error-rate Day 111   : 0.0155
# Error-rate Day 112   : 0.0151
# Error-rate Day 113   : 0.01565
# Error-rate Day 114   : 0.01825
# Error-rate Day 115   : 0.0218
# Error-rate Day 116   : 0.0181
# Error-rate Day 117   : 0.01745
# Error-rate Day 118   : 0.0147

# %%
import matplotlib.pyplot as plt

def plot5degree(error_rates, batch_size, scatter = False):
    
    # Set up the day_indexes with the missing 45th day in mind
    y_indexes = np.arange(0, 120)
    y_indexes = np.delete(y_indexes, 46)
    
    y = np.array(error_rates)
    y = y * 100
    x = y_indexes

    # create polynomial equation and calculate line
    theta = np.polyfit(x, y, 5)
    y_line = theta[5] + theta[4] * pow(x, 1) + theta[3] * pow(x, 2) + theta[2] * pow(x, 3) + theta[1] * pow(x, 4) + theta[0] * pow(x, 5)

    if (scatter):
        plt.scatter(x, y)
    
    plt.plot(x, y_line, 'r')
    plt.title('pa-continoues-fixed-feat with batch size {}'.format(batch_size))
    plt.xlabel('Days')
    plt.ylabel('Cumulative error rate')
    plt.ylim([0,6])
    plt.show()

plot5degree(error_rates, batch_size, True)
