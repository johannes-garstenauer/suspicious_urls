# %%
import scipy.io
data = scipy.io.loadmat('../../data/url.mat')

# %% [markdown]
# **create list for labels and data, where one entry is the data for the day with this index**

# %%
import numpy as np

num_of_days = 120
X, Y = [], []

for i in range(num_of_days):
    day_data = data["Day" + str(i)]
    X.append(day_data[0][0][0])
    Y.append(day_data[0][0][1])

# %% [markdown]
# **continous learn classifier**

# %%
def fix_features(X, fixed_features_amount = 150000):
    select_ind = np.arange(0, fixed_features_amount)
    return X[:,select_ind]

# %%
# incremental learns classifier (must have partial_fit() function)
# returns an array of cumulative error rates for each day
def learn_incremental(clf, batch_size = 1000):
    
    error_rates = []
    num_of_days = 120
    err = 0
    
    for curr_day in range(num_of_days): # looping through days
    
        if (curr_day != 45):
            X_curr_day = fix_features(X[curr_day])
    
            # split the data in slices of batch_size
            batches_amount = int(X_curr_day.shape[0] / batch_size)
            Y_curr_day = np.array_split(Y[curr_day], batches_amount)
    
            for j in range(batches_amount): # looping through individual urls
                select_ind = np.arange(j * batch_size, (j+1) * batch_size)
        
                X_curr_url_batch, Y_curr_url_batch = X_curr_day[select_ind,:], Y_curr_day[j] 
        
                # flatten y to 1d
                Y_curr_url_batch = Y_curr_url_batch.ravel()
        
                if (j > 0):
                    Y_preds = clf.predict(X_curr_url_batch)
            
                    for k in range(batch_size):
                        if(Y_preds[k] != Y_curr_url_batch[k]):
                            err = err + 1
        
                clf.partial_fit(X_curr_url_batch, Y_curr_url_batch, classes=list(range(2))) # Continous fitting of urls and label
            
            error_rates.append(err / X_curr_day.shape[0])
            err = 0
    return error_rates

# %%
from sklearn.linear_model import Perceptron

clf = Perceptron(random_state = 123)

batch_size = 50
error_rates = learn_incremental(clf, batch_size)

cnt = 0
for x in error_rates:    
    print("Error-rate Day {}   : {}".format(cnt, x))
    cnt = cnt + 1
# Out:
# Error-rate Day 0   : 0.0523125
# Error-rate Day 1   : 0.03585
# Error-rate Day 2   : 0.0283
# Error-rate Day 3   : 0.0241
# Error-rate Day 4   : 0.03035
# Error-rate Day 5   : 0.025
# Error-rate Day 6   : 0.0227
# Error-rate Day 7   : 0.0279
# Error-rate Day 8   : 0.02645
# Error-rate Day 9   : 0.03105
# Error-rate Day 10   : 0.0287
# Error-rate Day 11   : 0.0245
# Error-rate Day 12   : 0.026
# Error-rate Day 13   : 0.0184
# Error-rate Day 14   : 0.02355
# Error-rate Day 15   : 0.0191
# Error-rate Day 16   : 0.02165
# Error-rate Day 17   : 0.01775
# Error-rate Day 18   : 0.0204
# Error-rate Day 19   : 0.01625
# Error-rate Day 20   : 0.0204
# Error-rate Day 21   : 0.0265
# Error-rate Day 22   : 0.0216
# Error-rate Day 23   : 0.02355
# Error-rate Day 24   : 0.0301
# Error-rate Day 25   : 0.0306
# Error-rate Day 26   : 0.01785
# Error-rate Day 27   : 0.0208
# Error-rate Day 28   : 0.02245
# Error-rate Day 29   : 0.02405
# Error-rate Day 30   : 0.02995
# Error-rate Day 31   : 0.0237
# Error-rate Day 32   : 0.02535
# Error-rate Day 33   : 0.02415
# Error-rate Day 34   : 0.0004
# Error-rate Day 35   : 0.03025
# Error-rate Day 36   : 0.0016
# Error-rate Day 37   : 0.0005
# Error-rate Day 38   : 0.037
# Error-rate Day 39   : 0.034
# Error-rate Day 40   : 0.02595
# Error-rate Day 41   : 0.02025
# Error-rate Day 42   : 0.02675
# Error-rate Day 43   : 0.02225
# Error-rate Day 44   : 0.0162
# Error-rate Day 45   : 0.0227
# Error-rate Day 46   : 0.0203
# Error-rate Day 47   : 0.0233
# Error-rate Day 48   : 0.03055
# Error-rate Day 49   : 0.02955
# Error-rate Day 50   : 0.02245
# Error-rate Day 51   : 0.02535
# Error-rate Day 52   : 0.02635
# Error-rate Day 53   : 0.02025
# Error-rate Day 54   : 0.0212
# Error-rate Day 55   : 0.01925
# Error-rate Day 56   : 0.01855
# Error-rate Day 57   : 0.01765
# Error-rate Day 58   : 0.0188
# Error-rate Day 59   : 0.01775
# Error-rate Day 60   : 0.0163
# Error-rate Day 61   : 0.01865
# Error-rate Day 62   : 0.0211
# Error-rate Day 63   : 0.0173
# Error-rate Day 64   : 0.0223
# Error-rate Day 65   : 0.01805
# Error-rate Day 66   : 0.0183
# Error-rate Day 67   : 0.0174
# Error-rate Day 68   : 0.01435
# Error-rate Day 69   : 0.01655
# Error-rate Day 70   : 0.02385
# Error-rate Day 71   : 0.0217
# Error-rate Day 72   : 0.01985
# Error-rate Day 73   : 0.0193
# Error-rate Day 74   : 0.0231
# Error-rate Day 75   : 0.02155
# Error-rate Day 76   : 0.01755
# Error-rate Day 77   : 0.02165
# Error-rate Day 78   : 0.0263
# Error-rate Day 79   : 0.0215
# Error-rate Day 80   : 0.02115
# Error-rate Day 81   : 0.0121
# Error-rate Day 82   : 0.0139
# Error-rate Day 83   : 0.01695
# Error-rate Day 84   : 0.0196
# Error-rate Day 85   : 0.0131
# Error-rate Day 86   : 0.0133
# Error-rate Day 87   : 0.0146
# Error-rate Day 88   : 0.01145
# Error-rate Day 89   : 0.00975
# Error-rate Day 90   : 0.01265
# Error-rate Day 91   : 0.01705
# Error-rate Day 92   : 0.0181
# Error-rate Day 93   : 0.0173
# Error-rate Day 94   : 0.0098
# Error-rate Day 95   : 0.01325
# Error-rate Day 96   : 0.0158
# Error-rate Day 97   : 0.01675
# Error-rate Day 98   : 0.01995
# Error-rate Day 99   : 0.02225
# Error-rate Day 100   : 0.02055
# Error-rate Day 101   : 0.0229
# Error-rate Day 102   : 0.0166
# Error-rate Day 103   : 0.01365
# Error-rate Day 104   : 0.0165
# Error-rate Day 105   : 0.0161
# Error-rate Day 106   : 0.0135
# Error-rate Day 107   : 0.0193
# Error-rate Day 108   : 0.0156
# Error-rate Day 109   : 0.0141
# Error-rate Day 110   : 0.01475
# Error-rate Day 111   : 0.01605
# Error-rate Day 112   : 0.0167
# Error-rate Day 113   : 0.0152
# Error-rate Day 114   : 0.01745
# Error-rate Day 115   : 0.0203
# Error-rate Day 116   : 0.0127
# Error-rate Day 117   : 0.01535
# Error-rate Day 118   : 0.01425

# %%
import matplotlib.pyplot as plt

def plot5degree(error_rates, batch_size, scatter = False):
    
    # Set up the day_indexes with the missing 45th day in mind
    y_indexes = np.arange(0, 120)
    y_indexes = np.delete(y_indexes, 46)
    
    y = np.array(error_rates)
    y = y * 100
    x = y_indexes

    # create polynomial equation and calculate line
    theta = np.polyfit(x, y, 5)
    y_line = theta[5] + theta[4] * pow(x, 1) + theta[3] * pow(x, 2) + theta[2] * pow(x, 3) + theta[1] * pow(x, 4) + theta[0] * pow(x, 5)

    if (scatter):
        plt.scatter(x, y)
    
    plt.plot(x, y_line, 'r')
    plt.title('perceptron-cont-fixed-feat with batch size {}'.format(batch_size))
    plt.xlabel('Days')
    plt.ylabel('Cumulative error rate')
    plt.ylim([0,6])
    plt.show()

plot5degree(error_rates, batch_size, True)
