# %%
import scipy.io
data = scipy.io.loadmat('../../data/url.mat')

# %% [markdown]
# **create list for labels and data, where one entry is the data for the day with this index**

# %%
import numpy as np

num_of_days = 120
X, Y = [], []

for i in range(num_of_days):
    day_data = data["Day" + str(i)]
    X.append(day_data[0][0][0])
    Y.append(day_data[0][0][1])

# %% [markdown]
# **continous learn classifier**

# %%
def fix_features(X, fixed_features_amount = 150000):
    select_ind = np.arange(0, fixed_features_amount)
    return X[:,select_ind]

# %%
# incremental learns classifier (must have partial_fit() function)
# returns an array of cumulative error rates for each day
def learn_incremental(clf, batch_size = 1000):
    
    error_rates = []
    num_of_days = 120
    err = 0
    
    for curr_day in range(num_of_days): # looping through days
    
        if (curr_day != 45):
            X_curr_day = fix_features(X[curr_day])
    
            # split the data in slices of batch_size
            batches_amount = int(X_curr_day.shape[0] / batch_size)
            Y_curr_day = np.array_split(Y[curr_day], batches_amount)
    
            for j in range(batches_amount): # looping through individual urls
                select_ind = np.arange(j * batch_size, (j+1) * batch_size)
        
                X_curr_url_batch, Y_curr_url_batch = X_curr_day[select_ind,:], Y_curr_day[j] 
        
                # flatten y to 1d
                Y_curr_url_batch = Y_curr_url_batch.ravel()
        
                if (j > 0):
                    Y_preds = clf.predict(X_curr_url_batch)
            
                    for k in range(batch_size):
                        if(Y_preds[k] != Y_curr_url_batch[k]):
                            err = err + 1
        
                clf.partial_fit(X_curr_url_batch, Y_curr_url_batch, classes=list(range(2))) # Continous fitting of urls and label
            
            error_rates.append(err / X_curr_day.shape[0])
            err = 0
    return error_rates

# %%
from sklearn.linear_model import Perceptron

clf = Perceptron(random_state = 123)

batch_size = 4000
error_rates = learn_incremental(clf, batch_size)

cnt = 0
for x in error_rates:    
    print("Error-rate Day {}   : {}".format(cnt, x))
    cnt = cnt + 1
# Out:
# Error-rate Day 0   : 0.059
# Error-rate Day 1   : 0.0369
# Error-rate Day 2   : 0.02565
# Error-rate Day 3   : 0.02985
# Error-rate Day 4   : 0.0342
# Error-rate Day 5   : 0.0229
# Error-rate Day 6   : 0.02695
# Error-rate Day 7   : 0.0322
# Error-rate Day 8   : 0.03445
# Error-rate Day 9   : 0.03565
# Error-rate Day 10   : 0.03565
# Error-rate Day 11   : 0.02265
# Error-rate Day 12   : 0.0269
# Error-rate Day 13   : 0.02455
# Error-rate Day 14   : 0.02865
# Error-rate Day 15   : 0.0233
# Error-rate Day 16   : 0.0213
# Error-rate Day 17   : 0.01965
# Error-rate Day 18   : 0.02215
# Error-rate Day 19   : 0.02045
# Error-rate Day 20   : 0.02235
# Error-rate Day 21   : 0.02855
# Error-rate Day 22   : 0.0232
# Error-rate Day 23   : 0.02745
# Error-rate Day 24   : 0.029
# Error-rate Day 25   : 0.0337
# Error-rate Day 26   : 0.02355
# Error-rate Day 27   : 0.02085
# Error-rate Day 28   : 0.0278
# Error-rate Day 29   : 0.02745
# Error-rate Day 30   : 0.03605
# Error-rate Day 31   : 0.0325
# Error-rate Day 32   : 0.0324
# Error-rate Day 33   : 0.0275
# Error-rate Day 34   : 0.00035
# Error-rate Day 35   : 0.03905
# Error-rate Day 36   : 0.0056
# Error-rate Day 37   : 0.00025
# Error-rate Day 38   : 0.048
# Error-rate Day 39   : 0.0376
# Error-rate Day 40   : 0.03315
# Error-rate Day 41   : 0.02065
# Error-rate Day 42   : 0.02955
# Error-rate Day 43   : 0.0248
# Error-rate Day 44   : 0.01915
# Error-rate Day 45   : 0.0248
# Error-rate Day 46   : 0.0212
# Error-rate Day 47   : 0.02725
# Error-rate Day 48   : 0.03095
# Error-rate Day 49   : 0.03455
# Error-rate Day 50   : 0.02905
# Error-rate Day 51   : 0.0269
# Error-rate Day 52   : 0.0307
# Error-rate Day 53   : 0.02135
# Error-rate Day 54   : 0.0206
# Error-rate Day 55   : 0.02405
# Error-rate Day 56   : 0.0188
# Error-rate Day 57   : 0.02025
# Error-rate Day 58   : 0.0208
# Error-rate Day 59   : 0.02135
# Error-rate Day 60   : 0.0218
# Error-rate Day 61   : 0.02395
# Error-rate Day 62   : 0.02825
# Error-rate Day 63   : 0.0233
# Error-rate Day 64   : 0.02875
# Error-rate Day 65   : 0.02165
# Error-rate Day 66   : 0.0256
# Error-rate Day 67   : 0.0214
# Error-rate Day 68   : 0.0165
# Error-rate Day 69   : 0.0217
# Error-rate Day 70   : 0.0258
# Error-rate Day 71   : 0.0221
# Error-rate Day 72   : 0.0294
# Error-rate Day 73   : 0.02235
# Error-rate Day 74   : 0.0219
# Error-rate Day 75   : 0.02225
# Error-rate Day 76   : 0.0181
# Error-rate Day 77   : 0.02535
# Error-rate Day 78   : 0.03375
# Error-rate Day 79   : 0.0264
# Error-rate Day 80   : 0.0265
# Error-rate Day 81   : 0.01495
# Error-rate Day 82   : 0.01455
# Error-rate Day 83   : 0.0194
# Error-rate Day 84   : 0.02205
# Error-rate Day 85   : 0.01625
# Error-rate Day 86   : 0.0146
# Error-rate Day 87   : 0.01435
# Error-rate Day 88   : 0.01515
# Error-rate Day 89   : 0.01015
# Error-rate Day 90   : 0.0126
# Error-rate Day 91   : 0.02125
# Error-rate Day 92   : 0.01905
# Error-rate Day 93   : 0.01535
# Error-rate Day 94   : 0.01185
# Error-rate Day 95   : 0.0148
# Error-rate Day 96   : 0.0167
# Error-rate Day 97   : 0.01745
# Error-rate Day 98   : 0.0232
# Error-rate Day 99   : 0.02245
# Error-rate Day 100   : 0.0202
# Error-rate Day 101   : 0.02555
# Error-rate Day 102   : 0.0162
# Error-rate Day 103   : 0.01495
# Error-rate Day 104   : 0.019
# Error-rate Day 105   : 0.0163
# Error-rate Day 106   : 0.01475
# Error-rate Day 107   : 0.01945
# Error-rate Day 108   : 0.0137
# Error-rate Day 109   : 0.0133
# Error-rate Day 110   : 0.01505
# Error-rate Day 111   : 0.01765
# Error-rate Day 112   : 0.01865
# Error-rate Day 113   : 0.01835
# Error-rate Day 114   : 0.02205
# Error-rate Day 115   : 0.02575
# Error-rate Day 116   : 0.0157
# Error-rate Day 117   : 0.01725
# Error-rate Day 118   : 0.01515

# %%
import matplotlib.pyplot as plt

def plot5degree(error_rates, batch_size, scatter = False):
    
    # Set up the day_indexes with the missing 45th day in mind
    y_indexes = np.arange(0, 120)
    y_indexes = np.delete(y_indexes, 46)
    
    y = np.array(error_rates)
    y = y * 100
    x = y_indexes

    # create polynomial equation and calculate line
    theta = np.polyfit(x, y, 5)
    y_line = theta[5] + theta[4] * pow(x, 1) + theta[3] * pow(x, 2) + theta[2] * pow(x, 3) + theta[1] * pow(x, 4) + theta[0] * pow(x, 5)

    if (scatter):
        plt.scatter(x, y)
    
    plt.plot(x, y_line, 'r')
    plt.title('perceptron-cont-fixed-feat with batch size {}'.format(batch_size))
    plt.xlabel('Days')
    plt.ylabel('Cumulative error rate')
    plt.ylim([0,6])
    plt.show()

plot5degree(error_rates, batch_size, True)
